# %% [markdown]
# <a href="https://colab.research.google.com/github/esay2077/bigdata_analysis/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9D%84_%ED%99%9C%EC%9A%A9%ED%95%9C_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EC%BF%A1%EB%B6%81_3%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 데이터 랭글링

import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url, on_bad_lines = 'skip')
df.head(5)

#on_bad_lines 로 개정
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 데이터 프레임 만들기

import pandas as pd

df = pd.DataFrame()

df['name'] =['jk','ss']
df['age'] = [39,32]
df['driver'] = [True,False]
df
# Out:
#   name  age  driver
# 0   jk   39    True
# 1   ss   32   False

# %%
new_person = pd.Series(['mm',40,True],
                       index= ['name','age','driver'])
df._append(new_person, ignore_index = True)

#_append로 개정
# Out:
#   name  age  driver
# 0   jk   39    True
# 1   ss   32   False
# 2   mm   40    True

# %%
#넘파이배열
import numpy as np

data = [['jj',38,True],['ss',25, False]]

matrix = np.array(data)
pd.DataFrame(matrix,columns=['name','age','driver'])
# Out:
#   name age driver
# 0   jj  38   True
# 1   ss  25  False

# %%
#원본리스트
pd.DataFrame(data,columns=['name','age','driver'])
# Out:
#   name  age  driver
# 0   jj   38    True
# 1   ss   25   False

# %%
#딕셔너리
data = {'name':['kk','ss'],
        'age':[22,23],
        'driver':[True,False]}

pd.DataFrame(data)
# Out:
#   name  age  driver
# 0   kk   22    True
# 1   ss   23   False

# %%
# 매핑한 딕셔너리
data = [{'name':'jj','age':38,'driver':True},
        {'name':'ss','age':25,'driver':False}]

pd.DataFrame(data, index=['row1','row2'])
# Out:
#      name  age  driver
# row1   jj   38    True
# row2   ss   25   False

# %%
# 데이터 설명

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.shape #차원
# Out:
# (891, 12)

# %%
df.describe() #기술통계
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info() #상태확인 Age,Cabin,Embarked  결측치
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 데이터프레임 탐색

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df.iloc[0] # 첫 행 선택
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.iloc[:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df = df.set_index(df['Name']) #인덱스 지정

df.loc[['Allen, Miss. Elisabeth Walton']]
# Out:
#                                PassengerId  Survived  Pclass  \
# Name
# Allen, Miss. Elisabeth Walton          731         1       1
#
#                                                         Name     Sex   Age  \
# Name
# Allen, Miss. Elisabeth Walton  Allen, Miss. Elisabeth Walton  female  29.0
#
#                                SibSp  Parch Ticket      Fare Cabin Embarked
# Name
# Allen, Miss. Elisabeth Walton      0      0  24160  211.3375    B5        S

# %%
df.loc[['Allison, Miss. Helen Loraine'],['Age','Sex']]
# Out:
#                               Age     Sex
# Name
# Allison, Miss. Helen Loraine  2.0  female

# %%
df[:'Allison, Miss. Helen Loraine']
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Haas, Miss. Aloisia                                         294         0
# Mineff, Mr. Ivan                                            295         0
# Lewy, Mr. Ervin G                                           296         0
# Hanna, Mr. Mansour                                          297         0
# Allison, Miss. Helen Loraine                                298         0
#
#                                                     Pclass  \
# Name
# ...

# %%
df[['Age',"Sex"]].head(2)
# Out:
#                                                      Age     Sex
# Name
# Braund, Mr. Owen Harris                             22.0    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0  female

# %%
# 조건에 따른 행 선택

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df[df['Sex']=='female'].head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 조건 여러개
#여자이자 60세 이상
df[(df["Sex"] == 'female') & (df['Age']>=60)]
# Out:
#      PassengerId  Survived  Pclass  \
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 275      0   13502  77.9583    D7        S
# 366      0  110813  75.2500   D37        C
# 483      0    4134   9.5875   NaN        S
# 829      0  113572  80.0000   B28      NaN

# %%
# 값 치환하기

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df['Sex'].replace('female','Women').head(2)
# Out:
# 0     male
# 1    Women
# Name: Sex, dtype: object

# %%
df['Sex'].replace(['female','male'],['Woman','Man']).head(5)
# Out:
# 0      Man
# 1    Woman
# 2    Woman
# 3    Woman
# 4      Man
# Name: Sex, dtype: object

# %%
df.replace(1,'One').head(2)
# Out:
#   PassengerId Survived Pclass  \
# 0         One        0      3
# 1           2      One    One
#
#                                                 Name     Sex   Age SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0   One
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0   One
#
#   Parch     Ticket     Fare Cabin Embarked
# 0     0  A/5 21171   7.2500   NaN        S
# 1     0   PC 17599  71.2833   C85        C

# %%
df.replace(r'1st','Frist',regex=True).head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.replace(['female','male'],'person').head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris  person  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  person  38.0      1
# 2                             Heikkinen, Miss. Laina  person  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.replace({'female':1,'male':0}).head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S

# %%
# 열이름 바꾸기
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df= pd.read_csv(url)

df.rename(columns = {'Pclass':"Passenger Class"}).head(2)
# Out:
#    PassengerId  Survived  Passenger Class  \
# 0            1         0                3
# 1            2         1                1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.rename(columns={'Pclass':'Passenger Class','Sex':'Gender'}).head(2)
# Out:
#    PassengerId  Survived  Passenger Class  \
# 0            1         0                3
# 1            2         1                1
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
import collections

columns_names = collections.defaultdict(str)

for name in df.columns:
    columns_names[name]

columns_names
# Out:
# defaultdict(str,
#             {'PassengerId': '',
#              'Survived': '',
#              'Pclass': '',
#              'Name': '',
#              'Sex': '',
#              'Age': '',
#              'SibSp': '',
#              'Parch': '',
#              'Ticket': '',
#              'Fare': '',
#              'Cabin': '',
#              'Embarked': ''})

# %%
df.rename(index = {0:-1}).head(2)
# Out:
#     PassengerId  Survived  Pclass  \
# -1            1         0       3
#  1            2         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# -1                            Braund, Mr. Owen Harris    male  22.0      1
#  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#     Parch     Ticket     Fare Cabin Embarked
# -1      0  A/5 21171   7.2500   NaN        S
#  1      0   PC 17599  71.2833   C85        C

# %%
df.rename(str.lower,axis = 'columns').head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# 최솟값, 최댓값, 합,평균 계산 및 개수 세기

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df =pd.read_csv(url)

print('최댓값:',df['Age'].max())
print('최솟값:',df['Age'].min())
print('평균:',df['Age'].mean())
print('개수:',df['Age'].count())
print('합계:',df['Age'].sum())
# Out:
# 최댓값: 80.0
# 최솟값: 0.42
# 평균: 29.69911764705882
# 개수: 714
# 합계: 21205.17

# %%
df.count()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
num_cols = df.dtypes[df.dtypes !='object'].index.to_list()

cov = df[num_cols].cov()
cov
#개정후 수치열만 안찾아줌
# Out:
#               PassengerId  Survived     Pclass         Age      SibSp  \
# PassengerId  66231.000000 -0.626966  -7.561798  138.696504 -16.325843
# Survived        -0.626966  0.236772  -0.137703   -0.551296  -0.018954
# Pclass          -7.561798 -0.137703   0.699015   -4.496004   0.076599
# Age            138.696504 -0.551296  -4.496004  211.019125  -4.163334
# SibSp          -16.325843 -0.018954   0.076599   -4.163334   1.216043
# Parch           -0.342697  0.032017   0.012429   -2.344191   0.368739
# Fare           161.883369  6.221787 -22.830196   73.849030   8.748734
#
#                 Parch         Fare
# PassengerId -0.342697   161.883369
# Survived     0.032017     6.221787
# Pclass       0.012429   -22.830196
# Age         -2.344191    73.849030
# SibSp        0.368739     8.748734
# Parch        0.649728     8.661052
# Fare         8.661052  2469.436846

# %%
num_cols = df.dtypes[df.dtypes !='object'].index.to_list()

corr = df[num_cols].corr()

corr
#개정후 수치열만 안찾아줌
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# 고유한 값 찾기
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["Pclass"].nunique()
# Out:
# 3

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# 누락된 값 다루기

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

pd.read_csv(url)

df[df["Age"].isnull()].head(2)
# Out:
#     PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 5             6         0       3              Moran, Mr. James  male  NaN
# 17           18         1       2  Williams, Mr. Charles Eugene  male  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S

# %%
import numpy as np

df["Sex"] = df["Sex"].replace('male',np.nan)

# %%
df = pd.read_csv(url,na_filter = False)
df[12:14]
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex Age  \
# 12           13         0       3  Saundercock, Mr. William Henry  male  20
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39
#
#     SibSp  Parch     Ticket    Fare Cabin Embarked
# 12      0      0  A/5. 2151   8.050              S
# 13      1      5     347082  31.275              S

# %%
# 열 삭제 하기

import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df.drop('Age',axis= 1).head(2) # 열 삭제 axis = 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
df.drop(['Cabin','Embarked'],axis= 1).head(2) # 여러 열 삭제
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare
# 0      0  A/5 21171   7.2500
# 1      0   PC 17599  71.2833

# %%
df.drop(df.columns[0],axis =1).head(2) # 인덱스 지정 열 삭제
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
df_name_dropped = df.drop(df.columns[0],axis=1) # 수정한 데이터로 새 데이터 프레임 생성
df_name_dropped.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
# 행 삭제하기
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df[df['Sex']!= 'female'].head(2)
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 0            1         0       3   Braund, Mr. Owen Harris  male  22.0      1
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# 4      0     373450  8.05   NaN        S

# %%
df[df['Name']!= "Braund, Mr. Owen Harris"].head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df[df.index != 0].head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# 중복된 행 삭제하기

import pandas as pd
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.drop_duplicates().head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
print('원본 데이터프레임 행의 수:',len(df))
print('중복 삭제후 행의 수:', len(df.drop_duplicates()))
#완벽하게 동일한 행만 삭제
# Out:
# 원본 데이터프레임 행의 수: 891
# 중복 삭제후 행의 수: 891

# %%
df.drop_duplicates(subset=['Sex'])
# 중복된 행 삭제
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.drop_duplicates(subset=['Sex'],keep = 'last')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# 값에 따라 행을 그룹핑하기
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv('/titanic.csv')

df.groupby('Sex')["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Survived')['Name'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %%
df.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: Age, dtype: float64

# %%
# 시간에 따라 행 그룹핑
import numpy as np
import pandas as pd

#날짜 범위 date_range
time_index = pd.date_range('06/06/2017',periods = 100000, freq = '30s')

df = pd.DataFrame(index = time_index)

# 난수값으로 열 내용 구성
df["Sale_Amount"] = np.random.randint(1, 10 , 100000)

# 주단위 w 로 그룹핑 합계
df.resample('W').sum()
# 4일
df.resample('4D').sum()
# Out:
#             Sale_Amount
# 2017-06-06        57622
# 2017-06-10        57417
# 2017-06-14        57703
# 2017-06-18        57569
# 2017-06-22        57681
# 2017-06-26        57617
# 2017-06-30        57924
# 2017-07-04        57230
# 2017-07-08        39338

# %%
df.head(3)
# Out:
#                      Sale_Amount
# 2017-06-06 00:00:00            3
# 2017-06-06 00:00:30            9
# 2017-06-06 00:01:00            6

# %%
df.resample('2W').mean()
# Out:
#             Sale_Amount
# 2017-06-11     4.994560
# 2017-06-25     5.002133
# 2017-07-09     4.998016
# 2017-07-23     5.090865

# %%
df.resample('m').count()
# Out:
#             Sale_Amount
# 2017-06-30        72000
# 2017-07-31        28000

# %%
df.resample('m',label = 'left').count()
# Out:
#             Sale_Amount
# 2017-05-31        72000
# 2017-06-30        28000

# %%
# 열원소 순회하기
import pandas as pd

df = pd.read_csv('/titanic.csv')

for name in df['Name'][0:2]:
    print(name.lower())
#upper 대문자
#lower 소문자
# Out:
# braund, mr. owen harris
# cumings, mrs. john bradley (florence briggs thayer)

# %%
[name.upper() for name in df['Name'][0:2]]
# Out:
# ['BRAUND, MR. OWEN HARRIS',
#  'CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS THAYER)']

# %%
# 모든 열 원소에 함수 적용하기
# apply

import pandas as pd

df = pd.read_csv('/titanic.csv')

def uppercase(x):
    return x.upper()

df['Name'].apply(uppercase)[0:2] # apply(함수)
# Out:
# 0                              BRAUND, MR. OWEN HARRIS
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# Name: Name, dtype: object

# %%
df['Survived'].map({1:'Live',0:'Dead'})[:5]
# 1,0 을 Live, Dead 로 바꿈
# map({원래 속성:바뀐 속성})
# Out:
# 0    Dead
# 1    Live
# 2    Live
# 3    Live
# 4    Dead
# Name: Survived, dtype: object

# %%
df['Age'].apply(lambda x, age: x < age, age=30)[:5]
# lambda 매개변수 : 표현식
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
# Check data types
# df.dtypes

# Convert all elements to strings
df = df.astype(str)

# Apply max() function
df.apply(lambda x: max(x))
# Out:
# PassengerId                             99
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                    nan
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                                  93.5
# Cabin                                  nan
# Embarked                               nan
# dtype: object

# %%
def truncate_string(x):
    if type(x) == str:
        return x[:20] #문자열의 길이를 최대 20자로 축소
        return x

df.applymap(truncate_string)[:5]
# Out:
#   PassengerId Survived Pclass                  Name     Sex   Age SibSp Parch  \
# 0           1        0      3  Braund, Mr. Owen Har    male  22.0     1     0
# 1           2        1      1  Cumings, Mrs. John B  female  38.0     1     0
# 2           3        1      3  Heikkinen, Miss. Lai  female  26.0     0     0
# 3           4        1      1  Futrelle, Mrs. Jacqu  female  35.0     1     0
# 4           5        0      3  Allen, Mr. William H    male  35.0     0     0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171     7.25   nan        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282    7.925   nan        S
# 3            113803     53.1  C123        S
# 4            373450     8.05   nan        S

# %%
# 그룹에 함수 적용하기

import pandas as pd

df =pd.read_csv('/titanic.csv')
df.groupby('Sex').apply(lambda x : x.count())
# Out:
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Sex
# female          314       314     314   314  314  261    314    314     314
# male            577       577     577   577  577  453    577    577     577
#
#         Fare  Cabin  Embarked
# Sex
# female   314     97       312
# male     577    107       577

# %%
# 데이터 프레임 연결

import pandas as pd

data_a = {'id': ['1','2','3'],
          'first':['a','b','c'],
          'last':['d','e','f']}
df_a = pd.DataFrame(data_a, columns = [ 'id','first','last'])

data_b = {'id': ['4','5','6'],
          'first':['aa','bb','cc'],
          'last':['dd','ee','ff']}
df_b = pd.DataFrame(data_b, columns = [ 'id','first','last'])

pd.concat([df_a,df_b],axis = 0) # axis = 0 행방향으로 연결
# Out:
#   id first last
# 0  1     a    d
# 1  2     b    e
# 2  3     c    f
# 0  4    aa   dd
# 1  5    bb   ee
# 2  6    cc   ff

# %%
pd.concat([df_a,df_b],axis = 1) # 열방향
# Out:
#   id first last id first last
# 0  1     a    d  4    aa   dd
# 1  2     b    e  5    bb   ee
# 2  3     c    f  6    cc   ff

# %%
row = pd.Series([10,'Chris','Chillon'],index=['id','first','last'])

#df_a.append(row,ignore_index=True)
#판다 2.0부터, append(이전에 더 이상 사용되지 않음)가 제거되었다.
#대신 concat 사용해야 합니다

# %%
# 데이터프레임 병합하기

import pandas as pd

employee_data = {'employee_id': ['1','2','3','4'],
                 'name':['Amy','Allen','Alice','Tim']}
df_employees = pd.DataFrame(employee_data, columns = ['employee_id','name'])

sales_data = {'employee_id': ['3','4','5','6'],
                 'total_sales':['23456','2123','2345','4322']}
df_sales = pd.DataFrame(sales_data, columns = ['employee_id','total_sales'])

pd.merge(df_employees, df_sales, on = 'employee_id') #데이터 병합 (공통 id 3,4)
# Out:
#   employee_id   name total_sales
# 0           3  Alice       23456
# 1           4    Tim        2123

# %%
pd.merge(df_employees,df_sales, on = 'employee_id',how ='outer')
# Out:
#   employee_id   name total_sales
# 0           1    Amy         NaN
# 1           2  Allen         NaN
# 2           3  Alice       23456
# 3           4    Tim        2123
# 4           5    NaN        2345
# 5           6    NaN        4322

# %%
pd.merge(df_employees,df_sales, on= 'employee_id',how = 'left')
# Out:
#   employee_id   name total_sales
# 0           1    Amy         NaN
# 1           2  Allen         NaN
# 2           3  Alice       23456
# 3           4    Tim        2123

# %%
pd.merge(df_employees,df_sales,left_on = 'employee_id',right_on ='employee_id')
# Out:
#   employee_id   name total_sales
# 0           3  Alice       23456
# 1           4    Tim        2123
